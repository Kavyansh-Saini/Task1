# %% [markdown]
# <a href="https://colab.research.google.com/github/Kavyansh-Saini/Task1/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing Libraries

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
# %matplotlib inline

# %%
d=pd.read_csv('sales_data.csv')       #reading CSV file

# %%
d                   #checking CSV File
# Out:
#      ID Product  Quantity  Revenue
# 0     1       B         5       80
# 1     2       B         8      163
# 2     3       A         2       94
# 3     4       B         2       53
# 4     5       C         3      170
# ..  ...     ...       ...      ...
# 95   96       A         3      138
# 96   97       A         3       79
# 97   98       A         6       89
# 98   99       A         9      121
# 99  100       C         5       54
#
# [100 rows x 4 columns]

# %%
    # Selecting 1-D Arrays

revenue=d['Revenue']
ID=d['ID']
quantity=d['Quantity']
product=d['Product']

# %%
# Revenue Over ID  graph

plt.plot(ID,revenue,color='seagreen')
plt.title('Revenue Over ID')
plt.xlabel('ID')
plt.ylabel('Revenue')
plt.grid(linewidth=1, color = 'yellowgreen',)

# %%
#Revenue and Quantity Scatter Plot

plt.plot(quantity,revenue,'x' ,color='red')
plt.title('Relationship b/w Quantity and Revenue')
plt.xlabel('Quantity')
plt.ylabel('Revenue')
plt.grid(linestyle='--', linewidth=1,color='black')

# %%
#Product-Revenue Bar graph

plt.bar(product,revenue, width=0.5, color='yellow' ,)
plt.title('Total Revenue for each Product Category')
plt.xlabel('Category')
plt.ylabel('Revelue')
plt.grid(axis='y',linewidth=1,linestyle='--' ,color='black')
